# %% [markdown]
# ## Turning my data from tsv's into csv's while getting pandas to tell me the script i need to create a corresponding table in MySQL

# %%
import numpy as np
import pandas as pd

# %%
# read in SUB CSV

sub = pd.read_csv('/Users/markstansky/Desktop/Brainstation/Capstone/SEC/SEC  2023 08 Data/2023_08_notes/sub.tsv', sep='\t')

# %%
sub.head()
# Out:
#                    adsh   cik                                name     sic  \
# 0  0000002488-23-000135  2488          ADVANCED MICRO DEVICES INC  3674.0
# 1  0000004281-23-000016  4281               HOWMET AEROSPACE INC.  3350.0
# 2  0000004977-23-000146  4977                           AFLAC INC  6321.0
# 3  0000005272-23-000029  5272  AMERICAN INTERNATIONAL GROUP, INC.  6331.0
# 4  0000005513-23-000176  5513                          UNUM GROUP  6321.0
#
#   countryba stprba       cityba       zipba                      bas1  \
# 0        US     CA  SANTA CLARA       95054      2485 AUGUSTINE DRIVE
# 1        US     PA   PITTSBURGH  15212-5872       201 ISABELLA STREET
# 2        US     GA     COLUMBUS       31999           1932 WYNNTON RD
# 3        US     NY     NEW YORK  10020-1304  1271 AVE OF THE AMERICAS
# 4        US     TN  CHATTANOOGA       37402         1 FOUNTAIN SQUARE
#
#         bas2  ...               accepted prevrpt detail              instance  \
# ...

# %%
sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12602 entries, 0 to 12601
# Data columns (total 40 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   adsh         12602 non-null  object
#  1   cik          12602 non-null  int64
#  2   name         12602 non-null  object
#  3   sic          12204 non-null  float64
#  4   countryba    12588 non-null  object
#  5   stprba       11810 non-null  object
#  6   cityba       12588 non-null  object
#  7   zipba        12587 non-null  object
#  8   bas1         12588 non-null  object
#  9   bas2         5550 non-null   object
#  10  baph         12597 non-null  object
#  11  countryma    12579 non-null  object
#  12  stprma       11847 non-null  object
#  13  cityma       12580 non-null  object
#  14  zipma        12578 non-null  object
#  15  mas1         12577 non-null  object
#  16  mas2         5547 non-null   object
#  17  countryinc   11435 non-null  object
# ...

# %%
sub.tail()
#12,601 rows
# Out:
#                        adsh      cik  \
# 12597  0001840292-23-000038  1840292
# 12598  0001842279-23-000075  1842279
# 12599  0001903596-23-000691  1391426
# 12600  0001944057-23-000010  1944057
# 12601  0001946997-23-000008  1946997
#
#                                             name     sic countryba stprba  \
# 12597                             HELIOGEN, INC.  4911.0        US     CA
# 12598                            OPAL FUELS INC.  4932.0        US     MA
# 12599                          CLEAN VISION CORP  2860.0        US     CA
# 12600                               COOL CO LTD.  4400.0        BM    NaN
# 12601  EQT EXETER REAL ESTATE INCOME TRUST, INC.  6798.0        US     PA
#
#                 cityba  zipba                              bas1  \
# 12597         PASADENA  91103                   130 W UNION ST.
# 12598           BOSTON  02116  200 CLARENDON STREET, 55TH FLOOR
# 12599  MANHATTAN BEACH  90266            2711 N. SEPULVEDA BLVD
# ...

# %%
sub.to_csv('/Users/markstansky/Desktop/Brainstation/Capstone/SEC/SEC  2023 08 Data/2023_08_notes/CSV/sub.csv', index=False) # Set index=False to exclude the index column in the CSV

# %%
# pandas script for MySQL table

print_stmt = pd.io.sql.get_schema(sub, 'sub')
print(print_stmt)
# Out:
# CREATE TABLE "sub" (
# "adsh" TEXT,
#   "cik" INTEGER,
#   "name" TEXT,
#   "sic" REAL,
#   "countryba" TEXT,
#   "stprba" TEXT,
#   "cityba" TEXT,
#   "zipba" TEXT,
#   "bas1" TEXT,
#   "bas2" TEXT,
#   "baph" TEXT,
#   "countryma" TEXT,
#   "stprma" TEXT,
#   "cityma" TEXT,
#   "zipma" TEXT,
#   "mas1" TEXT,
#   "mas2" TEXT,
#   "countryinc" TEXT,
#   "stprinc" TEXT,
#   "ein" INTEGER,
#   "former" TEXT,
#   "changed" REAL,
#   "afs" TEXT,
#   "wksi" INTEGER,
#   "fye" REAL,
#   "form" TEXT,
#   "period" REAL,
#   "fy" REAL,
#   "fp" TEXT,
#   "filed" INTEGER,
#   "accepted" TEXT,
#   "prevrpt" INTEGER,
#   "detail" INTEGER,
#   "instance" TEXT,
#   "nciks" INTEGER,
#   "aciks" TEXT,
#   "pubfloatusd" REAL,
#   "floatdate" REAL,
#   "floataxis" TEXT,
#   "floatmems" REAL
# )

# %% [markdown]
# ## doing PRE database now

# %%
# read in SUB CSV

sub = pd.read_csv('/Users/markstansky/Desktop/Brainstation/Capstone/SEC/SEC  2023 08 Data/2023_08_notes/pre.tsv', sep='\t')

# %%
sub.head()
# Out:
#                    adsh   cik                                name     sic  \
# 0  0000002488-23-000135  2488          ADVANCED MICRO DEVICES INC  3674.0
# 1  0000004281-23-000016  4281               HOWMET AEROSPACE INC.  3350.0
# 2  0000004977-23-000146  4977                           AFLAC INC  6321.0
# 3  0000005272-23-000029  5272  AMERICAN INTERNATIONAL GROUP, INC.  6331.0
# 4  0000005513-23-000176  5513                          UNUM GROUP  6321.0
#
#   countryba stprba       cityba       zipba                      bas1  \
# 0        US     CA  SANTA CLARA       95054      2485 AUGUSTINE DRIVE
# 1        US     PA   PITTSBURGH  15212-5872       201 ISABELLA STREET
# 2        US     GA     COLUMBUS       31999           1932 WYNNTON RD
# 3        US     NY     NEW YORK  10020-1304  1271 AVE OF THE AMERICAS
# 4        US     TN  CHATTANOOGA       37402         1 FOUNTAIN SQUARE
#
#         bas2  ...               accepted prevrpt detail              instance  \
# ...

# %%
sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12602 entries, 0 to 12601
# Data columns (total 40 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   adsh         12602 non-null  object
#  1   cik          12602 non-null  int64
#  2   name         12602 non-null  object
#  3   sic          12204 non-null  float64
#  4   countryba    12588 non-null  object
#  5   stprba       11810 non-null  object
#  6   cityba       12588 non-null  object
#  7   zipba        12587 non-null  object
#  8   bas1         12588 non-null  object
#  9   bas2         5550 non-null   object
#  10  baph         12597 non-null  object
#  11  countryma    12579 non-null  object
#  12  stprma       11847 non-null  object
#  13  cityma       12580 non-null  object
#  14  zipma        12578 non-null  object
#  15  mas1         12577 non-null  object
#  16  mas2         5547 non-null   object
#  17  countryinc   11435 non-null  object
# ...

# %%
sub.tail()
#12,601 rows
# Out:
#                        adsh      cik  \
# 12597  0001840292-23-000038  1840292
# 12598  0001842279-23-000075  1842279
# 12599  0001903596-23-000691  1391426
# 12600  0001944057-23-000010  1944057
# 12601  0001946997-23-000008  1946997
#
#                                             name     sic countryba stprba  \
# 12597                             HELIOGEN, INC.  4911.0        US     CA
# 12598                            OPAL FUELS INC.  4932.0        US     MA
# 12599                          CLEAN VISION CORP  2860.0        US     CA
# 12600                               COOL CO LTD.  4400.0        BM    NaN
# 12601  EQT EXETER REAL ESTATE INCOME TRUST, INC.  6798.0        US     PA
#
#                 cityba  zipba                              bas1  \
# 12597         PASADENA  91103                   130 W UNION ST.
# 12598           BOSTON  02116  200 CLARENDON STREET, 55TH FLOOR
# 12599  MANHATTAN BEACH  90266            2711 N. SEPULVEDA BLVD
# ...

# %%
sub.to_csv('/Users/markstansky/Desktop/Brainstation/Capstone/SEC/SEC  2023 08 Data/2023_08_notes/CSV/sub.csv', index=False) # Set index=False to exclude the index column in the CSV

# %%
# pandas script for MySQL table

print_stmt = pd.io.sql.get_schema(sub, 'sub')
print(print_stmt)
# Out:
# CREATE TABLE "sub" (
# "adsh" TEXT,
#   "cik" INTEGER,
#   "name" TEXT,
#   "sic" REAL,
#   "countryba" TEXT,
#   "stprba" TEXT,
#   "cityba" TEXT,
#   "zipba" TEXT,
#   "bas1" TEXT,
#   "bas2" TEXT,
#   "baph" TEXT,
#   "countryma" TEXT,
#   "stprma" TEXT,
#   "cityma" TEXT,
#   "zipma" TEXT,
#   "mas1" TEXT,
#   "mas2" TEXT,
#   "countryinc" TEXT,
#   "stprinc" TEXT,
#   "ein" INTEGER,
#   "former" TEXT,
#   "changed" REAL,
#   "afs" TEXT,
#   "wksi" INTEGER,
#   "fye" REAL,
#   "form" TEXT,
#   "period" REAL,
#   "fy" REAL,
#   "fp" TEXT,
#   "filed" INTEGER,
#   "accepted" TEXT,
#   "prevrpt" INTEGER,
#   "detail" INTEGER,
#   "instance" TEXT,
#   "nciks" INTEGER,
#   "aciks" TEXT,
#   "pubfloatusd" REAL,
#   "floatdate" REAL,
#   "floataxis" TEXT,
#   "floatmems" REAL
# )
